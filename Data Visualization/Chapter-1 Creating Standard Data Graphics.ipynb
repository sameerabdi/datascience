# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

# %% [markdown]
# ### Creating a Line Chart

# %% [markdown]
# #### Plotting a Line Chart in matplotlib

# %%
x = range(1,10)
y =[1,2,3,4,0,4,3,2,1]

plt.plot(x,y)

# %% [markdown]
# #### Plotting a Line Chart in Pandas Object

# %%
address= 'C:/Users/samee/Documents/Python For DS Code/Data/mtcars.csv'
cars = pd.read_csv(address)
cars.columns=['car names', 'mpg','cyl','disp','hp','drat','wt','qsec','vs','am','gear','carb']
cars.head(3)
# Out:
#        car names   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0      Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1  Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2     Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
#
#    carb
# 0     4
# 1     4
# 2     1

# %%
mpg =cars['mpg']

# %%
mpg.plot()

# %%
df = cars[['cyl','wt','mpg']]

# %%
df.plot()

# %% [markdown]
# ### Creating Bar Charts

# %% [markdown]
# #### Creating Bar Chart From List

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# #### Creating Bar Chart From Pandas Object

# %%
mpg.plot(kind='bar')  ##barh for horizontal bar chart

# %% [markdown]
# ### Creating Pie Chart

# %%
x = [1,2,3,4,5,0]
plt.pie(x)
plt.show()

# %% [markdown]
# ### Saving Plot

# %%
plt.pie(x)
plt.savefig('pie_chart.png')
plt.show()

# %%
# %pwd #to get the image location
# Out:
# 'C:\\Users\\samee\\Documents\\Python For DS Code\\Data Visualization'
