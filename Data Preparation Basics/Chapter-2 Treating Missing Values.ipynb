# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %% [markdown]
# ## Figuring out What Data is Missing

# %%
missing = np.nan
series_obj = Series(['raw 1','raw 2',missing,'raw 4','raw 5',missing,'raw 7',missing])

# %%
series_obj
# Out:
# 0    raw 1
# 1    raw 2
# 2      NaN
# 3    raw 4
# 4    raw 5
# 5      NaN
# 6    raw 7
# 7      NaN
# dtype: object

# %%
series_obj.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6    False
# 7     True
# dtype: bool

# %% [markdown]
# ## Filling missing Values

# %%
np.random.seed(25) ## to get same random in diffrent system
DF_obj = DataFrame(np.random.rand(36).reshape(6,6))
DF_obj
# Out:
#           0         1         2         3         4         5
# 0  0.870124  0.582277  0.278839  0.185911  0.411100  0.117376
# 1  0.684969  0.437611  0.556229  0.367080  0.402366  0.113041
# 2  0.447031  0.585445  0.161985  0.520719  0.326051  0.699186
# 3  0.366395  0.836375  0.481343  0.516502  0.383048  0.997541
# 4  0.514244  0.559053  0.034450  0.719930  0.421004  0.436935
# 5  0.281701  0.900274  0.669612  0.456069  0.289804  0.525819

# %%
DF_obj.loc[3:5, 0] = missing
DF_obj.loc[1:3, 5] = missing
DF_obj
# Out:
#           0         1         2         3         4         5
# 0  0.870124  0.582277  0.278839  0.185911  0.411100  0.117376
# 1  0.684969  0.437611  0.556229  0.367080  0.402366       NaN
# 2  0.447031  0.585445  0.161985  0.520719  0.326051       NaN
# 3       NaN  0.836375  0.481343  0.516502  0.383048       NaN
# 4       NaN  0.559053  0.034450  0.719930  0.421004  0.436935
# 5       NaN  0.900274  0.669612  0.456069  0.289804  0.525819

# %%
filled_DF = DF_obj.fillna(0)

# %%
filled_DF
# Out:
#           0         1         2         3         4         5
# 0  0.870124  0.582277  0.278839  0.185911  0.411100  0.117376
# 1  0.684969  0.437611  0.556229  0.367080  0.402366  0.000000
# 2  0.447031  0.585445  0.161985  0.520719  0.326051  0.000000
# 3  0.000000  0.836375  0.481343  0.516502  0.383048  0.000000
# 4  0.000000  0.559053  0.034450  0.719930  0.421004  0.436935
# 5  0.000000  0.900274  0.669612  0.456069  0.289804  0.525819

# %%
filled_DF = DF_obj.fillna({0: 0.12, 5: 1.25})

# %%
filled_DF
# Out:
#           0         1         2         3         4         5
# 0  0.870124  0.582277  0.278839  0.185911  0.411100  0.117376
# 1  0.684969  0.437611  0.556229  0.367080  0.402366  1.250000
# 2  0.447031  0.585445  0.161985  0.520719  0.326051  1.250000
# 3  0.120000  0.836375  0.481343  0.516502  0.383048  1.250000
# 4  0.120000  0.559053  0.034450  0.719930  0.421004  0.436935
# 5  0.120000  0.900274  0.669612  0.456069  0.289804  0.525819

# %%
fill_DF = DF_obj.fillna(method='ffill')
fill_DF
# Out:
#           0         1         2         3         4         5
# 0  0.870124  0.582277  0.278839  0.185911  0.411100  0.117376
# 1  0.684969  0.437611  0.556229  0.367080  0.402366  0.117376
# 2  0.447031  0.585445  0.161985  0.520719  0.326051  0.117376
# 3  0.447031  0.836375  0.481343  0.516502  0.383048  0.117376
# 4  0.447031  0.559053  0.034450  0.719930  0.421004  0.436935
# 5  0.447031  0.900274  0.669612  0.456069  0.289804  0.525819

# %% [markdown]
# ## Counting Missing Values

# %%
np.random.seed(25) ## to get same random in diffrent system
DF_obj = DataFrame(np.random.rand(36).reshape(6,6))
DF_obj.loc[3:5, 0] = missing
DF_obj.loc[1:3, 5] = missing
DF_obj
DF_obj
# Out:
#           0         1         2         3         4         5
# 0  0.870124  0.582277  0.278839  0.185911  0.411100  0.117376
# 1  0.684969  0.437611  0.556229  0.367080  0.402366       NaN
# 2  0.447031  0.585445  0.161985  0.520719  0.326051       NaN
# 3       NaN  0.836375  0.481343  0.516502  0.383048       NaN
# 4       NaN  0.559053  0.034450  0.719930  0.421004  0.436935
# 5       NaN  0.900274  0.669612  0.456069  0.289804  0.525819

# %%
DF_obj.isnull().sum()
# Out:
# 0    3
# 1    0
# 2    0
# 3    0
# 4    0
# 5    3
# dtype: int64

# %%
DF_no_NaN = DF_obj.dropna() ## Drapping Rows
DF_no_NaN
# Out:
#           0         1         2         3       4         5
# 0  0.870124  0.582277  0.278839  0.185911  0.4111  0.117376

# %%
DF_no_NaN = DF_obj.dropna(axis=1) ## Dropping Columns
DF_no_NaN
# Out:
#           1         2         3         4
# 0  0.582277  0.278839  0.185911  0.411100
# 1  0.437611  0.556229  0.367080  0.402366
# 2  0.585445  0.161985  0.520719  0.326051
# 3  0.836375  0.481343  0.516502  0.383048
# 4  0.559053  0.034450  0.719930  0.421004
# 5  0.900274  0.669612  0.456069  0.289804
